# %%
# %matplotlib notebook
# %autosave 10
# %lsmagic
# print(plt.style.available)

import numpy as np
from pylab import *
from matplotlib import gridspec
from matplotlib import pyplot as plt
import subprocess


from mTOOLS import loadpdos, getpdos

# %%
# ! qe_collectpdos r
# ! python -c "import mQE; mQE.readqe()"

# %%
pdosin = loadpdos(file='./qerun.npz')
sel='1:2|spdf|u'; E, t, p = getpdos(pdosin,sel,sigma=0.2)
sel='1:2|s|u'; E, t, p1 = getpdos(pdosin,sel,sigma=0.2)
sel='1:2|p|u'; E, t, p2 = getpdos(pdosin,sel,sigma=0.2)
sel='1:2|d|u'; E, t, p3 = getpdos(pdosin,sel,sigma=0.2)
# Out:
# Effective Gaussian sigma is 0.2 eV; dE is 0.025 eV.
# Effective Gaussian sigma is 0.2 eV; dE is 0.025 eV.
# Effective Gaussian sigma is 0.2 eV; dE is 0.025 eV.
# Effective Gaussian sigma is 0.2 eV; dE is 0.025 eV.
# Effective Gaussian sigma is 0.2 eV; dE is 0.025 eV.
# Effective Gaussian sigma is 0.2 eV; dE is 0.025 eV.
# Effective Gaussian sigma is 0.2 eV; dE is 0.025 eV.
# Effective Gaussian sigma is 0.2 eV; dE is 0.025 eV.

# %%
fig = plt.figure(figsize=(7,7))

gs = gridspec.GridSpec(2, 1, height_ratios=[1,1] )    
gs.update(top=0.93, bottom=0.07, left=0.05, right=0.9, wspace=0.2, hspace=0.2)

ax=fig.add_subplot(gs[0])
ax.plot(E, t, 'k:', lw=1, mfc='k', ms=3, label='total')
ax.plot(E, p1, 'r-', lw=1, mfc='k', ms=3, label='s')
ax.plot(E, p2, 'g--', lw=1, mfc='k', ms=3, label='p')
ax.plot(E, p3, 'b:', lw=1, mfc='k', ms=3, label='d')
# Out:
# <img src="data:image/png;base64,..." width="700">
